# %% [markdown]
# # Cell Size Distribution of Microbial Communities

# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import sys
# !conda install --yes --prefix {sys.prefix} sympy
from sympy import *
import scipy as sc
init_printing() # for pretty-printing equations etc
from scipy import integrate
from scipy.stats import beta
import math
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# ### Basic Lotka-Volterra model for multiple species

# %% [markdown]
# The adapted equation of the Lotka-Volterra model is here:<br>
# <br>
# $\frac{dN}{dt} = N_{i}(r_{max,i} + \sum \limits _{j}a_{ij}N_{j})$<br>
# Where $N_{i}$ is the total biomass of species i, $r_{max,i}$ is the maximal growth rate of species i and $a_{ij}$ is the per capita competitive effect of species j on species i. $r_{max}$ and $a_{ij}$ scale with the average mass of a bacterium of that species (more info later). $a_{ii}$ represents the inverse of the carrying capacity for species i, which is usually -1.

# %% [markdown]
# Parameter|Dimension|Possible Values
# -----|-----|-----
# $N$|$M$|-
# $r_{max}$|$T^{-1}$|$10^{-3}$ to $1$
# $a_{ij}$|$M^{-1}$|$10^{-3}$ to $10^{3}$

# %%
#Solution at equilibrium (dN/dt = 0) for a 2-species system
r_m1, r_m2, N1, N2, a11, a12, a21, a22, t = var("r_m1, r_m2, N1, N2, a11, a12, a21, a22, t", real = True)
dN1_dt = N1*(r_m1 + a11*N1 + a12*N2)
dN2_dt = N2*(r_m2 + a21*N1 + a22*N2)

N1_eqlb = Eq(dN1_dt,0)
N2_eqlb = Eq(dN2_dt,0)

N1_eqlb_sol = solve(N1_eqlb, N2)
N2_eqlb_sol = solve(N2_eqlb, N1)

N1_eqlb_sol, N2_eqlb_sol
# Out:
# ⎛⎡-N₁⋅a₁₁ - rₘ₁⎤  ⎡-N₂⋅a₂₂ - rₘ₂⎤⎞
# ⎜⎢─────────────⎥, ⎢─────────────⎥⎟
# ⎝⎣     a₁₂     ⎦  ⎣     a₂₁     ⎦⎠

# %%
#define a function to calculate the sum in the equation
def sumf(Competition, Species, i):
    x = 0
    for j in range(len(Species)):
        x = x + Competition[i][j]*Species[j]
    return(x)

# %%
#parameters
t_vec = np.arange(0, 100., 0.01)
Species = 5 #number of species in the system
r_m = np.ones(Species) #max growth rate of each species
a = (random.rand(Species,Species)-0.5) #competition matrix
for i in range(5):
    a[i][i] = -1 #Diagonals = -1 (Carrying Capacity)

#initial condition
N10N20 = np.ones(Species)

#model and solution
def LV(N1N2, t, r_m2, a):
    dN_dt = np.empty(Species)
    for i in range(Species):
        dN_dt[i] = N1N2[i]*r_m[i]*(1 + sumf(a, N1N2, i))
    return dN_dt

N1N2_vec = integrate.odeint(LV, N10N20, t_vec, (r_m, a))

print(a)
#plot
plt.style.use('seaborn-darkgrid')
plt.plot(t_vec, N1N2_vec)
plt.xlabel('Time')
plt.ylabel('Population size')
plt.legend(['Species 1 ($N1$)', 'Species 2 ($N2$)', 'Species 3 ($N3$)', 'Species 4 ($N$)', 'Species 5 ($N$)'], loc='best')
# Out:
# [[-1.          0.22145096  0.28846014 -0.27540229  0.01763379]
#  [ 0.08613734 -1.          0.38069137 -0.10716094 -0.0464248 ]
#  [ 0.36108204 -0.36176773 -1.          0.25127701  0.24641114]
#  [-0.07815323  0.459506   -0.15930669 -1.          0.17394991]
#  [ 0.3167816   0.20223537  0.48401002 -0.22533805 -1.        ]]

# %% [markdown]
# ### Temperature-corrected Lotka-Volterra model with mass scaling

# %% [markdown]
# $\frac{dN}{dt} = N_{i}(Y_{0}m_{i}^{\alpha-1}e^{\frac{-E}{kT}} + \sum \limits _{j}a_{ij}(m_{i},T)N_{j})$<br>

# %% [markdown]
# Parameter|Dimension|Possible Values
# -----|-----|-----
# $N$|$M$|-
# $m$|$M$|~$10^{-12}$ g
# $\alpha-1$|-|$0.8$
# $Y_{0}$|$(TM)^{-1}$|$10^{22}$ to $10^{25}$
# $e^{\frac{-E}{kT}}$|-|$10^{-14}$ (for E = 0.85)
# $a_{ij}(m_{i},T)$|$M^{-1}$|$10^{-3}$ to $10^{3}$

# %% [markdown]
# According to DeLong the scaling exponent $\alpha$ for prokaryotes lies between 1.65 and 2.14 and not -0.75 like in vertebrates (Kleiber's Law). So, $\alpha-1$ would be between 0.65 and 1.14. Knowing $\alpha$ is important to determine the possible values of $Y_{0}$. <br>
# If we assume that $0.6 < \alpha-1 < 1$, $m_{i}^{\alpha-1}$ lies between $10^{-8}$ and $10^{-11}$ and with the temperature correction being around $10^{-14}$, $Y_{0}$ has to be at least $10^{22}$ and $10^{25}$ to obtain a realistic growth rate (~1).

# %%
Tcorr = math.exp(-0.85/(8.62*10**(-5)*310)) #Temperature correction
Tcorr*(10**(-7))**0.8
# Out:
# 3.850600100852319e-20

# %%
#prior distribution
m = beta.rvs(10, 10, loc=10, scale=3990, size=10000, random_state=None)*10**(-15)
plt.style.use(plt.style.available[15])  #15,25, 27
fig, ax = plt.subplots()
ax.hist(m, bins = 2500)
ax.set_xlabel('Body mass [g]', size=24)
ax.set_ylabel('Abundance', size=24)
ax.set_title('Prior Cell Size Distribution', size=35)
plt.savefig('AbundancePlot_Prior.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ###### Competition and Cooperation

# %%
#define a function to calculate the sum in the equation
def sumf(Competition, Species, i):
    x = 0
    for j in range(len(Species)):
        x = x + Competition[i][j]*Species[j]
    return(x)

#model and solution
def LV(N1N2, t, Y0, m, alpha, Tcorr, a):
    dN_dt = np.empty(Species)
    for i in range(Species):
        dN_dt[i] = N1N2[i]*Y0*m[i]**(alpha-1)*Tcorr*(1 + sumf(a, N1N2, i))
    return dN_dt

#global Parameters
t_vec = np.arange(0, 100., 0.01)
Species = 20 #number of species in the system
Runs = 10 #number of simulations
Y0 = 1.5*10**22
alpha = 1.8
Tcorr = math.exp(-0.85/(8.62*10**(-5)*310))

plt.style.use('seaborn-darkgrid')  
fig, axs = plt.subplots(2, Runs)
m_final = np.zeros([Runs, Species])
N1N2_final = np.zeros([Runs, Species])

for n in range(Runs): #run simulation multiple times
    #local Parameters
    m=[]
    a=[]
    m=beta.rvs(10, 10, loc=10, scale=3990, size=Species, random_state=None)*10**(-15) #random gaussian distributed mass of species ranging from 0.6*10^-12g to 1.4*10^-12g
    a = ((random.rand(Species,Species)-0.5)/10) #competition matrix
    for i in range(Species):
        a[i][i] = -1 #Diagonals = -1 (Carrying Capacity)

    #initial condition
    N10N20 = np.ones(Species)
    
    #ODE Solution and Plot
    N1N2_vec = integrate.odeint(LV, N10N20, t_vec, (Y0, m, alpha, Tcorr, a))
    axs[0,n].plot(t_vec, N1N2_vec)
    axs[0,n].set_xlabel('Time')
    axs[0,n].set_ylabel('Population size')
    
    #plot final size distribution
    axs[1,n].plot(m,N1N2_vec[10000-1],'bo')
    axs[1,n].set_xlabel('size')
    axs[1,n].set_ylabel('abundance')
    
    #save final size distribution in a cumulative array
    m_final[n] = m_final[n] + m
    N1N2_final[n] = N1N2_final[n] + N1N2_vec[10000-1]
    
print('done')
# Out:
# done

# %% [markdown]
# ##### Final size distribution:

# %%
m_f = np.concatenate(m_final)
N_f = np.concatenate(N1N2_final)
results = np.zeros([Runs*Species,2])
results[:,0] = m_f
results[:,1] = N_f
results_sorted = results[results[:, 1].argsort()] #sort sizes for abundance

x = 0
for i in range(len(results[:,1])):
    if results[i,1]<=10**(-5):
        x += 1
        
plt.style.use(plt.style.available[25])  #15,25, 27
fig, ax = plt.subplots()
ax.hist(results_sorted[x:,0], bins=250, weights=results_sorted[x:,1])
ax.set_xlabel('Body mass [g]', size=24)
ax.set_ylabel('Abundance', size=24)
ax.set_title('Cell Size Distribution Mixed', size=35)
plt.savefig('AbundancePlot_Mixed.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Cell Size Distribution Mutualism')

# %% [markdown]
# ###### only competition

# %%
#define a function to calculate the sum in the equation
def sumf(Competition, Species, i):
    x = 0
    for j in range(len(Species)):
        x = x + Competition[i][j]*Species[j]
    return(x)

#model and solution
def LV(N1N2, t, Y0, m, alpha, Tcorr, a):
    dN_dt = np.empty(Species)
    for i in range(Species):
        dN_dt[i] = N1N2[i]*Y0*m[i]**(alpha-1)*Tcorr*(1 + sumf(a, N1N2, i))
    return dN_dt

#global Parameters
t_vec = np.arange(0, 100., 0.01)
Species = 20 #number of species in the system
Runs = 50 #number of simulations
Y0 = 1.5*10**22
alpha = 1.8
Tcorr = math.exp(-0.85/(8.62*10**(-5)*310))

plt.style.use('seaborn-darkgrid')  
m_final = np.zeros([Runs, Species])
N1N2_final = np.zeros([Runs, Species])

for n in range(Runs): #run simulation multiple times
    #local Parameters
    m=[]
    a=[]
    m=beta.rvs(10, 10, loc=10, scale=3990, size=Species, random_state=None)*10**(-15) #random gaussian distributed mass of species ranging from 0.6*10^-12g to 1.4*10^-12g
    a = -(random.rand(Species,Species)/20) #competition matrix
    for i in range(Species):
        a[i][i] = -1 #Diagonals = -1 (Carrying Capacity)

    #initial condition
    N10N20 = np.ones(Species)
    
    #ODE Solution
    N1N2_vec = integrate.odeint(LV, N10N20, t_vec, (Y0, m, alpha, Tcorr, a))
       
    #save final size distribution in a cumulative array
    m_final[n] = m_final[n] + m
    N1N2_final[n] = N1N2_final[n] + N1N2_vec[10000-1]
    
print('done')

#final size distribution
m_f = np.concatenate(m_final)
N_f = np.concatenate(N1N2_final)
results = np.zeros([Runs*Species,2])
results[:,0] = m_f
results[:,1] = N_f
results_sorted = results[results[:, 1].argsort()] #sort sizes for abundance

x = 0
for i in range(len(results[:,1])):
    if results[i,1]<=10**(-5):
        x += 1
        
plt.style.use(plt.style.available[25])  #15,25, 27
fig, ax = plt.subplots()
ax.hist(results_sorted[x:,0], bins=250, weights=results_sorted[x:,1])
ax.set_xlabel('Body mass [g]', size=24)
ax.set_ylabel('Abundance', size=24)
ax.set_title('Competition', size=35)
plt.savefig('AbundancePlot_Competition.png', dpi=300, bbox_inches='tight')
# Out:
# done

# %% [markdown]
# ###### only Mutualism

# %%
#define a function to calculate the sum in the equation
def sumf(Competition, Species, i):
    x = 0
    for j in range(len(Species)):
        x = x + Competition[i][j]*Species[j]
    return(x)

#model and solution
def LV(N1N2, t, Y0, m, alpha, Tcorr, a):
    dN_dt = np.empty(Species)
    for i in range(Species):
        dN_dt[i] = N1N2[i]*Y0*m[i]**(alpha-1)*Tcorr*(1 + sumf(a, N1N2, i))
    return dN_dt

#global Parameters
t_vec = np.arange(0, 100., 0.01)
Species = 20 #number of species in the system
Runs = 50 #number of simulations
Y0 = 1.5*10**22
alpha = 1.8
Tcorr = math.exp(-0.85/(8.62*10**(-5)*310))

plt.style.use('seaborn-darkgrid')  
m_final = np.zeros([Runs, Species])
N1N2_final = np.zeros([Runs, Species])

for n in range(Runs): #run simulation multiple times
    #local Parameters
    m=[]
    a=[]
    m=beta.rvs(10, 10, loc=10, scale=3990, size=Species, random_state=None)*10**(-15) #random gaussian distributed mass of species ranging from 0.6*10^-12g to 1.4*10^-12g
    a = (random.rand(Species,Species)/20) #competition matrix
    for i in range(Species):
        a[i][i] = -1 #Diagonals = -1 (Carrying Capacity)

    #initial condition
    N10N20 = np.ones(Species)
    
    #ODE Solution
    N1N2_vec = integrate.odeint(LV, N10N20, t_vec, (Y0, m, alpha, Tcorr, a))
       
    #save final size distribution in a cumulative array
    m_final[n] = m_final[n] + m
    N1N2_final[n] = N1N2_final[n] + N1N2_vec[10000-1]
    
print('done')

#final size distribution
m_f = np.concatenate(m_final)
N_f = np.concatenate(N1N2_final)
results = np.zeros([Runs*Species,2])
results[:,0] = m_f
results[:,1] = N_f
results_sorted = results[results[:, 1].argsort()] #sort sizes for abundance

x = 0
for i in range(len(results[:,1])):
    if results[i,1]<=10**(-5):
        x += 1
        
plt.style.use(plt.style.available[25])  #15,25, 27
fig, ax = plt.subplots()
ax.hist(results_sorted[x:,0], bins=250, weights=results_sorted[x:,1])
ax.set_xlabel('Body mass [g]', size=24)
ax.set_ylabel('Abundance', size=24)
ax.set_title('Mutualism', size=35)
plt.savefig('AbundancePlot_Mutualism.png', dpi=300, bbox_inches='tight')
# Out:
# done
